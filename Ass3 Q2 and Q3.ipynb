# %%
# !pip install -q tensorflow seaborn scikit-learn matplotlib tqdm pandas

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
import numpy as np, matplotlib.pyplot as plt, seaborn as sns, pandas as pd
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def plot_history(history, title):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')
    plt.title(title+" Accuracy"); plt.legend()
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.title(title+" Loss"); plt.legend()
    plt.show()

def plot_cm(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(title); plt.xlabel('Predicted'); plt.ylabel('Actual')
    plt.show()

def plot_roc(y_true_onehot, y_pred_prob, title):
    plt.figure(figsize=(6,5))
    for i in range(y_true_onehot.shape[1]):
        fpr, tpr, _ = roc_curve(y_true_onehot[:,i], y_pred_prob[:,i])
        plt.plot(fpr, tpr, label=f'Class {i}')
    plt.plot([0,1],[0,1],'k--')
    plt.title(f"{title} ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()

def macro_auc(y_true_onehot, y_pred_prob):
    fpr,tpr,roc_auc={},{},{}
    for i in range(y_true_onehot.shape[1]):
        fpr[i],tpr[i],_ = roc_curve(y_true_onehot[:,i], y_pred_prob[:,i])
        roc_auc[i]=auc(fpr[i],tpr[i])
    return np.mean(list(roc_auc.values()))

# %%
(m_x_train, m_y_train),(m_x_test, m_y_test)=keras.datasets.mnist.load_data()
m_x_all = np.concatenate([m_x_train, m_x_test]).astype('float32')/255.0
m_x_all = np.expand_dims(m_x_all,-1)
m_y_all = np.concatenate([m_y_train, m_y_test])
m_y_all_cat = to_categorical(m_y_all,10)
m_x_all_vgg = tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(m_x_all)),[32,32]).numpy()

# CIFAR-10
(c_x_train,c_y_train),(c_x_test,c_y_test)=keras.datasets.cifar10.load_data()
c_x_all = np.concatenate([c_x_train,c_x_test]).astype('float32')/255.0
c_y_all = np.concatenate([c_y_train,c_y_test]).flatten()
c_y_all_cat = to_categorical(c_y_all,10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
def build_cnn(input_shape,n_classes):
    model=models.Sequential([
        layers.Conv2D(32,3,activation='relu',padding='same',input_shape=input_shape),
        layers.Conv2D(32,3,activation='relu',padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,activation='relu',padding='same'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_vgg16(input_shape,n_classes):
    base=VGG16(include_top=False,weights=None,input_shape=input_shape)
    x=layers.Flatten()(base.output)
    x=layers.Dense(256,activation='relu')(x)
    out=layers.Dense(n_classes,activation='softmax')(x)
    model=models.Model(base.input,out)
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_alexnet_small(input_shape,n_classes):
    model=models.Sequential([
        layers.Conv2D(64,(3,3),activation='relu',padding='same',input_shape=input_shape),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(128,(3,3),activation='relu',padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(256,(3,3),activation='relu',padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Flatten(),
        layers.Dense(512,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_inceptionv3(input_shape, n_classes):
    """Builds a model using the InceptionV3 architecture as a base."""
    # Note: InceptionV3 requires input images to be at least 75x75.
    base = InceptionV3(include_top=False, weights=None, input_shape=input_shape)
    x = layers.GlobalAveragePooling2D()(base.output) # GlobalAveragePooling2D is often preferred over Flatten
    x = layers.Dense(512, activation='relu')(x)
    out = layers.Dense(n_classes, activation='softmax')(x)
    model = models.Model(base.input, out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_rnn(input_shape,n_classes):
    model=models.Sequential([
        layers.Input(shape=(input_shape[0],input_shape[1])),
        layers.LSTM(128),
        layers.Dense(128,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
def train_and_eval(model,X_train,y_train,X_test,y_test,y_test_cat,name,dataset,split_ratio):
    hist=model.fit(X_train,y_train,validation_split=0.1,epochs=5,batch_size=128,verbose=2)
    eval_res=model.evaluate(X_test,y_test_cat,verbose=0)
    preds=model.predict(X_test)
    pred_labels=np.argmax(preds,axis=1)
    rocA=macro_auc(y_test_cat,preds)
    report=classification_report(y_test,pred_labels,output_dict=True,zero_division=0)
    acc,prec,rec,f1=eval_res[1],report['weighted avg']['precision'],report['weighted avg']['recall'],report['weighted avg']['f1-score']
    return {"Dataset":dataset,"Model":name,"Split":split_ratio,"Accuracy":acc,"Precision":prec,"Recall":rec,"F1":f1,"AUC":rocA,"History":hist,"Y_true":y_test,"Y_pred":preds}

# %%
results=[]
splits = [0.6,0.7,0.8]

# %%
mnist_models=[
    ("CNN", build_cnn((28,28,1),10)),
    ("VGG16", build_vgg16((32,32,3),10)),
    ("AlexNet", build_alexnet_small((32,32,3),10)),
    ("InceptionNet", build_inceptionv3((32,32,3),10)),
    ("RNN", build_rnn((28,28),10))
]

for split in splits:
    X_train, X_test, y_train, y_test = train_test_split(m_x_all, m_y_all, train_size=split, random_state=42, stratify=m_y_all)
    X_train_cat, X_test_cat = to_categorical(y_train,10), to_categorical(y_test,10)
    X_train_vgg, X_test_vgg = tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_train)),[32,32]).numpy(), \
                               tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_test)),[32,32]).numpy()

    for name, model in mnist_models:
        if name in ["VGG16","AlexNet","InceptionNet"]:
            res=train_and_eval(model,X_train_vgg,X_train_cat,X_test_vgg,y_test,X_test_cat,name,"MNIST",split)
        elif name=="RNN":
            res=train_and_eval(model,X_train[:,:,0],X_train_cat,X_test[:,:,0],y_test,X_test_cat,name,"MNIST",split)
        else:
            res=train_and_eval(model,X_train,X_train_cat,X_test,y_test,X_test_cat,name,"MNIST",split)
        results.append(res)
# Out:
# Epoch 1/5
# 296/296 - 10s - 33ms/step - accuracy: 0.9297 - loss: 0.2311 - val_accuracy: 0.9748 - val_loss: 0.0816
# Epoch 2/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9826 - loss: 0.0545 - val_accuracy: 0.9821 - val_loss: 0.0530
# Epoch 3/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9888 - loss: 0.0353 - val_accuracy: 0.9857 - val_loss: 0.0450
# Epoch 4/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9910 - loss: 0.0269 - val_accuracy: 0.9860 - val_loss: 0.0495
# Epoch 5/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9935 - loss: 0.0200 - val_accuracy: 0.9881 - val_loss: 0.0381
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 49s - 167ms/step - accuracy: 0.1117 - loss: 2.3032 - val_accuracy: 0.1126 - val_loss: 2.3013
# Epoch 2/5
# 296/296 - 23s - 77ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 3/5
# 296/296 - 23s - 77ms/step - accuracy: 0.1125 - loss: 2.3013 - val_accuracy: 0.1126 - val_loss: 2.3016
# Epoch 4/5
# 296/296 - 23s - 76ms/step - accuracy: 0.1125 - loss: 2.3013 - val_accuracy: 0.1126 - val_loss: 2.3015
# Epoch 5/5
# 296/296 - 23s - 76ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3013
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step
# Epoch 1/5
# 296/296 - 9s - 31ms/step - accuracy: 0.9455 - loss: 0.1707 - val_accuracy: 0.9864 - val_loss: 0.0449
# Epoch 2/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9869 - loss: 0.0415 - val_accuracy: 0.9871 - val_loss: 0.0423
# Epoch 3/5
# 296/296 - 3s - 12ms/step - accuracy: 0.9912 - loss: 0.0281 - val_accuracy: 0.9867 - val_loss: 0.0460
# Epoch 4/5
# 296/296 - 3s - 12ms/step - accuracy: 0.9932 - loss: 0.0207 - val_accuracy: 0.9902 - val_loss: 0.0300
# Epoch 5/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9933 - val_loss: 0.0206
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 20s - 66ms/step - accuracy: 0.9571 - loss: 0.1353 - val_accuracy: 0.9855 - val_loss: 0.0500
# Epoch 2/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9879 - loss: 0.0369 - val_accuracy: 0.9869 - val_loss: 0.0411
# Epoch 3/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9922 - loss: 0.0226 - val_accuracy: 0.9869 - val_loss: 0.0362
# Epoch 4/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9947 - loss: 0.0157 - val_accuracy: 0.9900 - val_loss: 0.0340
# Epoch 5/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9957 - loss: 0.0134 - val_accuracy: 0.9902 - val_loss: 0.0392
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Epoch 1/5
# 296/296 - 7s - 22ms/step - accuracy: 0.1111 - loss: 2.3019 - val_accuracy: 0.1126 - val_loss: 2.3017
# Epoch 2/5
# 296/296 - 2s - 6ms/step - accuracy: 0.1125 - loss: 2.3016 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 3/5
# 296/296 - 2s - 6ms/step - accuracy: 0.1125 - loss: 2.3015 - val_accuracy: 0.1126 - val_loss: 2.3012
# Epoch 4/5
# 296/296 - 2s - 6ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 5/5
# 296/296 - 2s - 8ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3014
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 345/345 - 5s - 16ms/step - accuracy: 0.9934 - loss: 0.0214 - val_accuracy: 0.9916 - val_loss: 0.0245
# Epoch 2/5
# 345/345 - 7s - 21ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.9949 - val_loss: 0.0179
# Epoch 3/5
# 345/345 - 2s - 7ms/step - accuracy: 0.9962 - loss: 0.0105 - val_accuracy: 0.9947 - val_loss: 0.0206
# Epoch 4/5
# 345/345 - 3s - 7ms/step - accuracy: 0.9969 - loss: 0.0093 - val_accuracy: 0.9933 - val_loss: 0.0240
# Epoch 5/5
# 345/345 - 2s - 7ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.9920 - val_loss: 0.0274
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 345/345 - 37s - 108ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3009
# Epoch 2/5
# 345/345 - 26s - 76ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# Epoch 3/5
# 345/345 - 26s - 76ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# Epoch 4/5
# 345/345 - 26s - 77ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3007
# Epoch 5/5
# 345/345 - 26s - 76ms/step - accuracy: 0.1124 - loss: 2.3013 - val_accuracy: 0.1133 - val_loss: 2.3008
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Epoch 1/5
# 345/345 - 6s - 18ms/step - accuracy: 0.9938 - loss: 0.0202 - val_accuracy: 0.9953 - val_loss: 0.0200
# Epoch 2/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9953 - loss: 0.0139 - val_accuracy: 0.9884 - val_loss: 0.0308
# Epoch 3/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9968 - loss: 0.0096 - val_accuracy: 0.9939 - val_loss: 0.0205
# Epoch 4/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9970 - loss: 0.0087 - val_accuracy: 0.9933 - val_loss: 0.0258
# Epoch 5/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9961 - loss: 0.0110 - val_accuracy: 0.9961 - val_loss: 0.0157
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 345/345 - 14s - 40ms/step - accuracy: 0.9944 - loss: 0.0173 - val_accuracy: 0.9935 - val_loss: 0.0176
# Epoch 2/5
# 345/345 - 17s - 48ms/step - accuracy: 0.9962 - loss: 0.0108 - val_accuracy: 0.9949 - val_loss: 0.0144
# Epoch 3/5
# 345/345 - 10s - 30ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9953 - val_loss: 0.0158
# Epoch 4/5
# 345/345 - 10s - 30ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 0.9949 - val_loss: 0.0166
# Epoch 5/5
# 345/345 - 10s - 30ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9943 - val_loss: 0.0217
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 345/345 - 3s - 8ms/step - accuracy: 0.1124 - loss: 2.3015 - val_accuracy: 0.1133 - val_loss: 2.3011
# Epoch 2/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3009
# Epoch 3/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3009
# Epoch 4/5
# 345/345 - 2s - 7ms/step - accuracy: 0.1124 - loss: 2.3013 - val_accuracy: 0.1133 - val_loss: 2.3012
# Epoch 5/5
# 345/345 - 3s - 8ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 394/394 - 5s - 13ms/step - accuracy: 0.9959 - loss: 0.0140 - val_accuracy: 0.9962 - val_loss: 0.0106
# Epoch 2/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.9954 - val_loss: 0.0131
# Epoch 3/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9943 - val_loss: 0.0201
# Epoch 4/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9971 - val_loss: 0.0114
# Epoch 5/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9946 - val_loss: 0.0164
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 394/394 - 42s - 106ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3023
# Epoch 2/5
# 394/394 - 30s - 76ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3020
# Epoch 3/5
# 394/394 - 30s - 76ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3022
# Epoch 4/5
# 394/394 - 30s - 76ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3021
# Epoch 5/5
# 394/394 - 30s - 76ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3024
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Epoch 1/5
# 394/394 - 7s - 18ms/step - accuracy: 0.9962 - loss: 0.0131 - val_accuracy: 0.9966 - val_loss: 0.0106
# Epoch 2/5
# 394/394 - 5s - 13ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9959 - val_loss: 0.0120
# Epoch 3/5
# 394/394 - 6s - 16ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9937 - val_loss: 0.0246
# Epoch 4/5
# 394/394 - 5s - 12ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.9954 - val_loss: 0.0187
# Epoch 5/5
# 394/394 - 5s - 12ms/step - accuracy: 0.9978 - loss: 0.0072 - val_accuracy: 0.9941 - val_loss: 0.0187
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/5
# 394/394 - 16s - 40ms/step - accuracy: 0.9967 - loss: 0.0119 - val_accuracy: 0.9962 - val_loss: 0.0102
# Epoch 2/5
# 394/394 - 12s - 29ms/step - accuracy: 0.9979 - loss: 0.0075 - val_accuracy: 0.9970 - val_loss: 0.0116
# Epoch 3/5
# 394/394 - 12s - 29ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9975 - val_loss: 0.0123
# Epoch 4/5
# 394/394 - 12s - 30ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9954 - val_loss: 0.0178
# Epoch 5/5
# 394/394 - 12s - 29ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9957 - val_loss: 0.0165
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 394/394 - 3s - 8ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3021
# Epoch 2/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3024
# Epoch 3/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3024
# Epoch 4/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3021
# Epoch 5/5
# 394/394 - 3s - 7ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3021
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
cifar_models=[
    ("CNN", build_cnn((32,32,3),10)),
    ("VGG16", build_vgg16((32,32,3),10)),
    ("AlexNet", build_alexnet_small((32,32,3),10)),
    ("InceptionNet", build_inceptionv3((32,32,3),10)),
    ("RNN", build_rnn((32,32*3),10))
]

for split in splits:
    X_train, X_test, y_train, y_test = train_test_split(c_x_all, c_y_all, train_size=split, random_state=42, stratify=c_y_all)
    X_train_cat, X_test_cat = to_categorical(y_train,10), to_categorical(y_test,10)

    for name, model in cifar_models:
        if name=="RNN":
            X_train_rnn = X_train.reshape(-1,32,32*3)
            X_test_rnn = X_test.reshape(-1,32,32*3)
            res=train_and_eval(model,X_train_rnn,X_train_cat,X_test_rnn,y_test,X_test_cat,name,"CIFAR10",split)
        else:
            res=train_and_eval(model,X_train,X_train_cat,X_test,y_test,X_test_cat,name,"CIFAR10",split)
        results.append(res)
# Out:
# Epoch 1/5
# 254/254 - 9s - 36ms/step - accuracy: 0.4127 - loss: 1.6312 - val_accuracy: 0.4994 - val_loss: 1.3911
# Epoch 2/5
# 254/254 - 2s - 9ms/step - accuracy: 0.5748 - loss: 1.2029 - val_accuracy: 0.5908 - val_loss: 1.1782
# Epoch 3/5
# 254/254 - 2s - 9ms/step - accuracy: 0.6529 - loss: 0.9927 - val_accuracy: 0.6628 - val_loss: 0.9832
# Epoch 4/5
# 254/254 - 2s - 9ms/step - accuracy: 0.6960 - loss: 0.8742 - val_accuracy: 0.6703 - val_loss: 0.9364
# Epoch 5/5
# 254/254 - 2s - 9ms/step - accuracy: 0.7305 - loss: 0.7746 - val_accuracy: 0.6672 - val_loss: 0.9796
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 254/254 - 37s - 147ms/step - accuracy: 0.0950 - loss: 2.3030 - val_accuracy: 0.0994 - val_loss: 2.3028
# Epoch 2/5
# 254/254 - 20s - 78ms/step - accuracy: 0.0992 - loss: 2.3027 - val_accuracy: 0.0975 - val_loss: 2.3027
# Epoch 3/5
# 254/254 - 20s - 78ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 4/5
# 254/254 - 20s - 78ms/step - accuracy: 0.0973 - loss: 2.3027 - val_accuracy: 0.0922 - val_loss: 2.3027
# Epoch 5/5
# 254/254 - 20s - 78ms/step - accuracy: 0.0973 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3027
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# Epoch 1/5
# 254/254 - 9s - 36ms/step - accuracy: 0.4403 - loss: 1.5352 - val_accuracy: 0.5531 - val_loss: 1.2425
# Epoch 2/5
# 254/254 - 3s - 12ms/step - accuracy: 0.6148 - loss: 1.0914 - val_accuracy: 0.6219 - val_loss: 1.0688
# Epoch 3/5
# 254/254 - 3s - 12ms/step - accuracy: 0.6849 - loss: 0.8960 - val_accuracy: 0.6903 - val_loss: 0.9179
# Epoch 4/5
# 254/254 - 3s - 12ms/step - accuracy: 0.7426 - loss: 0.7493 - val_accuracy: 0.6756 - val_loss: 0.9328
# Epoch 5/5
# 254/254 - 3s - 13ms/step - accuracy: 0.7785 - loss: 0.6340 - val_accuracy: 0.7247 - val_loss: 0.8113
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 254/254 - 13s - 53ms/step - accuracy: 0.4298 - loss: 1.5873 - val_accuracy: 0.5253 - val_loss: 1.3422
# Epoch 2/5
# 254/254 - 8s - 30ms/step - accuracy: 0.6236 - loss: 1.0726 - val_accuracy: 0.6572 - val_loss: 0.9739
# Epoch 3/5
# 254/254 - 8s - 31ms/step - accuracy: 0.7040 - loss: 0.8455 - val_accuracy: 0.6744 - val_loss: 0.9243
# Epoch 4/5
# 254/254 - 8s - 31ms/step - accuracy: 0.7578 - loss: 0.6948 - val_accuracy: 0.6903 - val_loss: 0.8944
# Epoch 5/5
# 254/254 - 8s - 31ms/step - accuracy: 0.8109 - loss: 0.5394 - val_accuracy: 0.7197 - val_loss: 0.8298
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Epoch 1/5
# 254/254 - 3s - 13ms/step - accuracy: 0.3024 - loss: 1.9018 - val_accuracy: 0.3347 - val_loss: 1.7797
# Epoch 2/5
# 254/254 - 2s - 7ms/step - accuracy: 0.3998 - loss: 1.6576 - val_accuracy: 0.4053 - val_loss: 1.6300
# Epoch 3/5
# 254/254 - 2s - 7ms/step - accuracy: 0.4410 - loss: 1.5475 - val_accuracy: 0.4533 - val_loss: 1.5190
# Epoch 4/5
# 254/254 - 2s - 7ms/step - accuracy: 0.4694 - loss: 1.4695 - val_accuracy: 0.4667 - val_loss: 1.4775
# Epoch 5/5
# 254/254 - 2s - 9ms/step - accuracy: 0.4897 - loss: 1.4062 - val_accuracy: 0.4525 - val_loss: 1.5352
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 6s - 19ms/step - accuracy: 0.7431 - loss: 0.7455 - val_accuracy: 0.7312 - val_loss: 0.7670
# Epoch 2/5
# 296/296 - 2s - 8ms/step - accuracy: 0.7723 - loss: 0.6632 - val_accuracy: 0.7536 - val_loss: 0.7302
# Epoch 3/5
# 296/296 - 2s - 8ms/step - accuracy: 0.7961 - loss: 0.5883 - val_accuracy: 0.7252 - val_loss: 0.8249
# Epoch 4/5
# 296/296 - 2s - 8ms/step - accuracy: 0.8213 - loss: 0.5193 - val_accuracy: 0.7579 - val_loss: 0.7280
# Epoch 5/5
# 296/296 - 3s - 9ms/step - accuracy: 0.8445 - loss: 0.4494 - val_accuracy: 0.7343 - val_loss: 0.8170
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 296/296 - 27s - 92ms/step - accuracy: 0.1000 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3030
# Epoch 2/5
# 296/296 - 23s - 77ms/step - accuracy: 0.0980 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3030
# Epoch 3/5
# 296/296 - 23s - 77ms/step - accuracy: 0.0971 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3030
# Epoch 4/5
# 296/296 - 23s - 77ms/step - accuracy: 0.0995 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3030
# Epoch 5/5
# 296/296 - 23s - 77ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3031
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Epoch 1/5
# 296/296 - 5s - 18ms/step - accuracy: 0.7983 - loss: 0.5901 - val_accuracy: 0.7755 - val_loss: 0.6369
# Epoch 2/5
# 296/296 - 4s - 12ms/step - accuracy: 0.8366 - loss: 0.4753 - val_accuracy: 0.7981 - val_loss: 0.6001
# Epoch 3/5
# 296/296 - 4s - 12ms/step - accuracy: 0.8730 - loss: 0.3686 - val_accuracy: 0.8000 - val_loss: 0.5936
# Epoch 4/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9031 - loss: 0.2787 - val_accuracy: 0.7967 - val_loss: 0.6485
# Epoch 5/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9338 - loss: 0.1934 - val_accuracy: 0.7926 - val_loss: 0.6695
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 296/296 - 11s - 36ms/step - accuracy: 0.8269 - loss: 0.5124 - val_accuracy: 0.8260 - val_loss: 0.5272
# Epoch 2/5
# 296/296 - 9s - 30ms/step - accuracy: 0.8798 - loss: 0.3524 - val_accuracy: 0.8064 - val_loss: 0.5823
# Epoch 3/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9249 - loss: 0.2234 - val_accuracy: 0.7943 - val_loss: 0.6784
# Epoch 4/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9583 - loss: 0.1265 - val_accuracy: 0.8133 - val_loss: 0.6859
# Epoch 5/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9749 - loss: 0.0772 - val_accuracy: 0.7988 - val_loss: 0.8422
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 296/296 - 3s - 9ms/step - accuracy: 0.5024 - loss: 1.3785 - val_accuracy: 0.5117 - val_loss: 1.3567
# Epoch 2/5
# 296/296 - 2s - 8ms/step - accuracy: 0.5224 - loss: 1.3232 - val_accuracy: 0.5310 - val_loss: 1.3125
# Epoch 3/5
# 296/296 - 2s - 7ms/step - accuracy: 0.5417 - loss: 1.2751 - val_accuracy: 0.5221 - val_loss: 1.3211
# Epoch 4/5
# 296/296 - 2s - 6ms/step - accuracy: 0.5553 - loss: 1.2322 - val_accuracy: 0.5405 - val_loss: 1.2807
# Epoch 5/5
# 296/296 - 2s - 6ms/step - accuracy: 0.5651 - loss: 1.2032 - val_accuracy: 0.5479 - val_loss: 1.2704
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 338/338 - 5s - 16ms/step - accuracy: 0.8341 - loss: 0.4975 - val_accuracy: 0.8119 - val_loss: 0.5506
# Epoch 2/5
# 338/338 - 3s - 8ms/step - accuracy: 0.8612 - loss: 0.4127 - val_accuracy: 0.8148 - val_loss: 0.5613
# Epoch 3/5
# 338/338 - 3s - 9ms/step - accuracy: 0.8841 - loss: 0.3413 - val_accuracy: 0.8040 - val_loss: 0.6071
# Epoch 4/5
# 338/338 - 3s - 8ms/step - accuracy: 0.9040 - loss: 0.2811 - val_accuracy: 0.7994 - val_loss: 0.6459
# Epoch 5/5
# 338/338 - 3s - 9ms/step - accuracy: 0.9229 - loss: 0.2281 - val_accuracy: 0.7875 - val_loss: 0.7075
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 338/338 - 37s - 109ms/step - accuracy: 0.0984 - loss: 2.3027 - val_accuracy: 0.0944 - val_loss: 2.3029
# Epoch 2/5
# 338/338 - 26s - 77ms/step - accuracy: 0.0990 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3030
# Epoch 3/5
# 338/338 - 26s - 78ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3031
# Epoch 4/5
# 338/338 - 26s - 78ms/step - accuracy: 0.0986 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3028
# Epoch 5/5
# 338/338 - 26s - 78ms/step - accuracy: 0.0994 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3030
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# Epoch 1/5
# 338/338 - 7s - 22ms/step - accuracy: 0.9056 - loss: 0.3041 - val_accuracy: 0.9031 - val_loss: 0.3112
# Epoch 2/5
# 338/338 - 4s - 13ms/step - accuracy: 0.9394 - loss: 0.1872 - val_accuracy: 0.8831 - val_loss: 0.3798
# Epoch 3/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9580 - loss: 0.1269 - val_accuracy: 0.8796 - val_loss: 0.3957
# Epoch 4/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9723 - loss: 0.0850 - val_accuracy: 0.8838 - val_loss: 0.4061
# Epoch 5/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9775 - loss: 0.0676 - val_accuracy: 0.8631 - val_loss: 0.4808
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 338/338 - 14s - 41ms/step - accuracy: 0.9213 - loss: 0.2785 - val_accuracy: 0.9069 - val_loss: 0.3171
# Epoch 2/5
# 338/338 - 10s - 30ms/step - accuracy: 0.9663 - loss: 0.1111 - val_accuracy: 0.9081 - val_loss: 0.3444
# Epoch 3/5
# 338/338 - 10s - 31ms/step - accuracy: 0.9789 - loss: 0.0653 - val_accuracy: 0.8944 - val_loss: 0.4264
# Epoch 4/5
# 338/338 - 10s - 31ms/step - accuracy: 0.9834 - loss: 0.0490 - val_accuracy: 0.9008 - val_loss: 0.4488
# Epoch 5/5
# 338/338 - 10s - 30ms/step - accuracy: 0.9853 - loss: 0.0445 - val_accuracy: 0.8756 - val_loss: 0.5888
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/5
# 338/338 - 2s - 7ms/step - accuracy: 0.5735 - loss: 1.1918 - val_accuracy: 0.5725 - val_loss: 1.1598
# Epoch 2/5
# 338/338 - 3s - 9ms/step - accuracy: 0.5856 - loss: 1.1536 - val_accuracy: 0.5675 - val_loss: 1.2104
# Epoch 3/5
# 338/338 - 2s - 7ms/step - accuracy: 0.5969 - loss: 1.1189 - val_accuracy: 0.5810 - val_loss: 1.1505
# Epoch 4/5
# 338/338 - 2s - 6ms/step - accuracy: 0.6090 - loss: 1.0833 - val_accuracy: 0.5773 - val_loss: 1.1798
# Epoch 5/5
# 338/338 - 2s - 6ms/step - accuracy: 0.6224 - loss: 1.0513 - val_accuracy: 0.5910 - val_loss: 1.1613
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
df=pd.DataFrame(results)
print("\n=== Final Deep Learning Comparison Table (Multiple Splits) ===")
display(df)
df.to_csv("DeepLearning_Comparison_MultiSplits.csv",index=False)
print("Saved DeepLearning_Comparison_MultiSplits.csv ✅")
# Out:
# === Final Deep Learning Comparison Table (Multiple Splits) ===
#     Dataset      Model  Split  Accuracy  Precision    Recall        F1  \
# 0     MNIST        CNN    0.6  0.987214   0.987245  0.987214  0.987207
# 1     MNIST      VGG16    0.6  0.112536   0.012664  0.112536  0.022767
# 2     MNIST    AlexNet    0.6  0.988893   0.988950  0.988893  0.988887
# 3     MNIST  GoogLeNet    0.6  0.986143   0.986385  0.986143  0.986155
# 4     MNIST        RNN    0.6  0.112536   0.012664  0.112536  0.022767
# 5     MNIST        CNN    0.7  0.987095   0.987175  0.987095  0.987102
# 6     MNIST      VGG16    0.7  0.112524   0.012662  0.112524  0.022762
# 7     MNIST    AlexNet    0.7  0.992571   0.992597  0.992571  0.992574
# 8     MNIST  GoogLeNet    0.7  0.990952   0.990973  0.990952  0.990951
# 9     MNIST        RNN    0.7  0.112524   0.012662  0.112524  0.022762
# 10    MNIST        CNN    0.8  0.990286   0.990316  0.990286  0.990286
# 11    MNIST      VGG16    0.8  0.112500   0.012656  0.112500  0.022753
# 12    MNIST    AlexNet    0.8  0.991786   0.991844  0.991786  0.991795
# 13    MNIST  GoogLeNet    0.8  0.990571   0.990605  0.990571  0.990573
# 14    MNIST        RNN    0.8  0.112500   0.012656  0.112500  0.022753
# 15  CIFAR10        CNN    0.6  0.666000   0.692507  0.666000  0.665470
# 16  CIFAR10      VGG16    0.6  0.100000   0.010000  0.100000  0.018182
# 17  CIFAR10    AlexNet    0.6  0.723375   0.730318  0.723375  0.722122
# 18  CIFAR10  GoogLeNet    0.6  0.710042   0.723249  0.710042  0.708805
# 19  CIFAR10        RNN    0.6  0.457833   0.485729  0.457833  0.455852
# 20  CIFAR10        CNN    0.7  0.706667   0.720511  0.706667  0.709065
# 21  CIFAR10      VGG16    0.7  0.100000   0.010000  0.100000  0.018182
# 22  CIFAR10    AlexNet    0.7  0.750722   0.749827  0.750722  0.748447
# 23  CIFAR10  GoogLeNet    0.7  0.733000   0.730694  0.733000  0.729060
# 24  CIFAR10        RNN    0.7  0.535056   0.532228  0.535056  0.529780
# 25  CIFAR10        CNN    0.8  0.718333   0.719212  0.718333  0.717164
# 26  CIFAR10      VGG16    0.8  0.100000   0.010000  0.100000  0.018182
# 27  CIFAR10    AlexNet    0.8  0.758750   0.761554  0.758750  0.759521
# 28  CIFAR10  GoogLeNet    0.8  0.732417   0.738968  0.732417  0.733254
# 29  CIFAR10        RNN    0.8  0.556750   0.557486  0.556750  0.550195
#
#          AUC                                            History  \
# 0   0.999856  <keras.src.callbacks.history.History object at...
# 1   0.500000  <keras.src.callbacks.history.History object at...
# 2   0.999883  <keras.src.callbacks.history.History object at...
# 3   0.999843  <keras.src.callbacks.history.History object at...
# 4   0.500062  <keras.src.callbacks.history.History object at...
# 5   0.999846  <keras.src.callbacks.history.History object at...
# 6   0.500000  <keras.src.callbacks.history.History object at...
# 7   0.999864  <keras.src.callbacks.history.History object at...
# 8   0.999900  <keras.src.callbacks.history.History object at...
# 9   0.499938  <keras.src.callbacks.history.History object at...
# 10  0.999923  <keras.src.callbacks.history.History object at...
# 11  0.500018  <keras.src.callbacks.history.History object at...
# 12  0.999918  <keras.src.callbacks.history.History object at...
# 13  0.999940  <keras.src.callbacks.history.History object at...
# 14  0.499972  <keras.src.callbacks.history.History object at...
# 15  0.949018  <keras.src.callbacks.history.History object at...
# 16  0.500000  <keras.src.callbacks.history.History object at...
# 17  0.961363  <keras.src.callbacks.history.History object at...
# 18  0.959779  <keras.src.callbacks.history.History object at...
# 19  0.871257  <keras.src.callbacks.history.History object at...
# 20  0.956216  <keras.src.callbacks.history.History object at...
# 21  0.500000  <keras.src.callbacks.history.History object at...
# 22  0.965996  <keras.src.callbacks.history.History object at...
# 23  0.960879  <keras.src.callbacks.history.History object at...
# 24  0.901002  <keras.src.callbacks.history.History object at...
# 25  0.957138  <keras.src.callbacks.history.History object at...
# 26  0.500000  <keras.src.callbacks.history.History object at...
# 27  0.967099  <keras.src.callbacks.history.History object at...
# 28  0.960376  <keras.src.callbacks.history.History object at...
# 29  0.910799  <keras.src.callbacks.history.History object at...
#
#                                                Y_true  \
# 0   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 1   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 2   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 3   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 4   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 5   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 6   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 7   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 8   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 9   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 10  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 11  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 12  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 13  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 14  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 15  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 16  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 17  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 18  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 19  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 20  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 21  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 22  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 23  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 24  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 25  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 26  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 27  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 28  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 29  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
#
#                                                Y_pred
# 0   [[1.3460024e-09, 3.7772743e-10, 3.2063383e-09,...
# 1   [[0.10008535, 0.11268248, 0.09982916, 0.101555...
# 2   [[4.6681286e-09, 2.7557696e-09, 2.8484417e-09,...
# 3   [[5.866818e-14, 3.1067197e-12, 1.9324835e-11, ...
# 4   [[0.09861565, 0.110228635, 0.10096819, 0.10251...
# 5   [[1.2360536e-26, 3.15988e-18, 1.5442205e-18, 7...
# 6   [[0.0995594, 0.111520454, 0.099733375, 0.10383...
# 7   [[1.7713924e-15, 5.799967e-12, 2.3414293e-11, ...
# 8   [[2.7233698e-21, 1.0326209e-16, 4.6157166e-14,...
# 9   [[0.09790743, 0.112642445, 0.099692516, 0.1020...
# 10  [[2.9838764e-12, 2.550428e-13, 4.2278976e-13, ...
# 11  [[0.09938651, 0.11478721, 0.098155305, 0.10235...
# 12  [[5.286588e-14, 2.8196616e-12, 1.0393711e-12, ...
# 13  [[2.221904e-19, 1.2104334e-16, 3.089906e-20, 2...
# 14  [[0.09887632, 0.11223746, 0.09970141, 0.102818...
# 15  [[0.00017860794, 2.6719556e-05, 0.0020395343, ...
# 16  [[0.09994486, 0.10003741, 0.100731604, 0.10017...
# 17  [[0.00029107163, 1.8888253e-05, 0.00068510504,...
# 18  [[3.8839703e-06, 2.025541e-06, 6.951254e-05, 0...
# 19  [[0.0111988885, 0.012276517, 0.17494787, 0.172...
# 20  [[9.844717e-06, 4.9026494e-07, 0.9876791, 0.00...
# 21  [[0.09890917, 0.099807106, 0.098928414, 0.1015...
# 22  [[3.960371e-06, 4.053293e-07, 0.31084898, 0.00...
# 23  [[4.2781473e-08, 2.5257659e-08, 0.07996158, 0....
# 24  [[0.013867178, 0.0061353385, 0.080813244, 0.04...
# 25  [[9.951418e-06, 0.06653906, 1.183612e-05, 0.61...
# 26  [[0.09875026, 0.099677116, 0.09950434, 0.10108...
# 27  [[6.353412e-09, 6.811021e-08, 2.325915e-08, 0....
# 28  [[1.0608263e-05, 1.1696922e-09, 1.2209471e-10,...
# 29  [[0.0034781878, 0.0007549191, 0.010821511, 0.3...
# Saved DeepLearning_Comparison_MultiSplits.csv ✅

# %%
best_cases = df.loc[df.groupby(['Dataset','Model'])['Accuracy'].idxmax()]

# %%
for idx, row in best_cases.iterrows():
    hist = row['History']
    y_true = row['Y_true']
    y_pred = row['Y_pred']
    plot_history(hist,f"{row['Dataset']} {row['Model']} best split={row['Split']}")
    pred_labels = np.argmax(y_pred,axis=1)
    plot_cm(y_true,pred_labels,f"{row['Dataset']} {row['Model']} best split={row['Split']}")
    plot_roc(to_categorical(y_true,10), y_pred, f"{row['Dataset']} {row['Model']} best split={row['Split']}")

# %%
best_cases.drop(columns=['History','Y_true','Y_pred'], inplace=True)
best_cases.to_csv("DeepLearning_BestCase_Comparison.csv",index=False)
print("Saved DeepLearning_BestCase_Comparison.csv ✅")
display(best_cases)
# Out:
# Saved DeepLearning_BestCase_Comparison.csv ✅
#     Dataset      Model  Split  Accuracy  Precision    Recall        F1  \
# 27  CIFAR10    AlexNet    0.8  0.758750   0.761554  0.758750  0.759521
# 25  CIFAR10        CNN    0.8  0.718333   0.719212  0.718333  0.717164
# 23  CIFAR10  GoogLeNet    0.7  0.733000   0.730694  0.733000  0.729060
# 29  CIFAR10        RNN    0.8  0.556750   0.557486  0.556750  0.550195
# 16  CIFAR10      VGG16    0.6  0.100000   0.010000  0.100000  0.018182
# 7     MNIST    AlexNet    0.7  0.992571   0.992597  0.992571  0.992574
# 10    MNIST        CNN    0.8  0.990286   0.990316  0.990286  0.990286
# 8     MNIST  GoogLeNet    0.7  0.990952   0.990973  0.990952  0.990951
# 4     MNIST        RNN    0.6  0.112536   0.012664  0.112536  0.022767
# 1     MNIST      VGG16    0.6  0.112536   0.012664  0.112536  0.022767
#
#          AUC
# 27  0.967099
# 25  0.957138
# 23  0.960879
# 29  0.910799
# 16  0.500000
# 7   0.999864
# 10  0.999923
# 8   0.999900
# 4   0.500062
# 1   0.500000
